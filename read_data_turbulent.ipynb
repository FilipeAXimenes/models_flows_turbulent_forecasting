# %%
import numpy as np
import scipy.io
import glob
import os
import matplotlib.pyplot as plt
from scipy.signal import welch
import re
from tqdm import tqdm  # Para a barra de progresso
import matplotlib.ticker as ticker  # Para formatação dos rótulos dos eixos

# Diretório onde os arquivos .mat estão localizados
data_dir = 'C:/Users/FilipeAraujoXimenes/Documents/TG1/TG2/Data'

# Listar todos os arquivos .mat
filenames = glob.glob(os.path.join(data_dir, '*.mat'))

# Função para extrair o tempo do nome do arquivo
def extract_time(filename):
    base = os.path.basename(filename)
    # Procurar por 'qfour' seguido por números e possível ponto decimal
    match = re.match(r'qfour([\d\.]+)\.mat$', base)
    if match:
        return float(match.group(1))
    else:
        # Retornar float('inf') para arquivos que não correspondem ao padrão
        return float('inf')

# Ordenar os arquivos com base no tempo extraído
filenames = sorted(filenames, key=extract_time)

# Remover quaisquer arquivos que não conseguiram ser processados corretamente
filenames = [f for f in filenames if extract_time(f) != float('inf')]

# Atualizar N após a filtragem
N = len(filenames)

# Verificar se há arquivos para processar
if N == 0:
    raise ValueError("Nenhum arquivo .mat encontrado no diretório ou arquivos não seguem o padrão 'qfour<num>.mat'.")

# Carregar o primeiro arquivo para obter x, y, z
mat = scipy.io.loadmat(filenames[0])
x = mat['x'].flatten()
y = mat['y'].flatten()
z = mat['z'].flatten()

dx = x[1] - x[0]
Lx = x[-1] + dx
dz = z[1] - z[0]
Lz = z[-1] + dz

dalpha = 2 * np.pi / Lx
dbeta = 2 * np.pi / Lz
alphas = np.arange(0, 5) * dalpha
betas = np.arange(0, 11) * dbeta

# Evitar divisão por zero
epsilon = np.finfo(float).eps
alphas[0] = epsilon
betas[0] = epsilon

lambdax = 2 * np.pi / alphas
lambdaz = 2 * np.pi / betas

Retau = 180

lambdaxp = Retau * lambdax
lambdazp = Retau * lambdaz

lxptarget = 1000
lzptarget = 100

# Encontrar as posições mais próximas dos comprimentos de onda alvo
posa = np.argmin(np.abs(lambdaxp - lxptarget))
posb = np.argmin(np.abs(lambdazp - lzptarget))

ny = len(y)
ts = np.zeros(N)
X = np.zeros((3 * ny, N), dtype=complex)

# Loop para construir a matriz de dados X com tratamento de exceções
for i, filename in enumerate(tqdm(filenames, desc="Processando arquivos .mat")):
    try:
        ts[i] = extract_time(filename)
        mat = scipy.io.loadmat(filename)
        qfour = mat['qfour']
        
        # Verificação para garantir que o formato dos dados está correto
        if qfour.shape[0] <= posa or qfour.shape[2] <= posb:
            print(f"Dimensões incorretas no arquivo: {filename}, ignorando este arquivo.")
            continue
        
        X[:, i] = np.concatenate([
            qfour[posa, :, posb, 0].flatten(),  # u
            qfour[posa, :, posb, 1].flatten(),  # v
            qfour[posa, :, posb, 2].flatten()   # w
        ])
    
    except KeyError as e:
        print(f"Chave não encontrada no arquivo {filename}: {e}, ignorando este arquivo.")
    except Exception as e:
        print(f"Erro ao processar o arquivo {filename}: {e}, ignorando este arquivo.")

# Ordenar os dados por tempo
index = np.argsort(ts)
ts = ts[index]
X = X[:, index]

print(f"Número de arquivos processados: {N}")
print(f"Tamanho de ts: {ts.shape}")

# Função para ajustar os valores para a escala logarítmica base 10
def log_adjust_base10(data, threshold=1e-30):  # Threshold ajustado para valores muito pequenos
    data_adjusted = np.copy(data)
    data_adjusted[data_adjusted < threshold] = threshold
    return np.log10(data_adjusted)  # Log base 10 normal

# Função para configurar o eixo y sem notação científica
def format_labels(ax):
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Função para plotar os autovalores com tratamento de negativos e zero
def plot_autovalores(D, epsilon, title):
    # Ajustar os autovalores positivos para log
    D_pos = D.copy()
    D_pos[D < epsilon] = epsilon  # Substituir valores negativos e próximos de zero por epsilon

    # Plotar autovalores negativos em módulo
    if np.any(D < 0):
        D_neg = -D[D < 0]  # Inverter o sinal dos negativos para plotar em módulo
        
        # Primeiro gráfico com valores negativos em módulo
        fig, ax = plt.subplots()
        ax.plot(np.arange(len(D_neg)), D_neg, 'ro-', label='Autovalores Negativos (Módulo)')
        ax.set_xlabel('Índice do Autovalor')
        ax.set_ylabel('Valor Absoluto dos Autovalores Negativos')
        ax.set_title('Autovalores Negativos em Módulo')
        format_labels(ax)  # Aplicar formatação de rótulos
        plt.legend()
        plt.savefig('autovalores_negativos_modulo.png')
        plt.close()

        # Agora em log base 10
        D_neg_log10 = log_adjust_base10(D_neg)
        fig, ax = plt.subplots()
        ax.plot(np.arange(len(D_neg_log10)), D_neg_log10, 'ro-', label='Autovalores Negativos (Log Base 10)')
        ax.set_xlabel('Índice do Autovalor')
        ax.set_ylabel('Log Base 10 dos Autovalores Negativos')
        ax.set_title('Autovalores Negativos em Log Base 10')

        # Ajustar limites do eixo y para melhor visualização
        y_min, y_max = np.min(D_neg_log10), np.max(D_neg_log10)
        ax.set_ylim([y_min - 0.1, y_max + 0.1])  # Margem pequena para ajuste visual
        format_labels(ax)  # Aplicar formatação de rótulos
        plt.legend()
        plt.savefig('autovalores_negativos_log10.png')
        plt.close()

    # Criar figura para autovalores positivos e zero
    fig, ax = plt.subplots()
    ax.semilogy(np.arange(len(D_pos)), D_pos, 'b-', label='Autovalores Positivos ou Zero (Ajustados)')
    ax.set_xlabel('Índice do Autovalor')
    ax.set_ylabel('Valor do Autovalor (log)')
    ax.set_title(title)
    format_labels(ax)  # Aplicar formatação de rótulos
    plt.legend()
    plt.savefig('autovalores_positivos_ajustados.png')
    plt.close()

# Ordenar os dados por tempo
index = np.argsort(ts)
ts = ts[index]
X = X[:, index]

# Plotar dados
plt.figure(101)
plt.plot(ts)
plt.grid(True)
plt.title('Tempo ts')
plt.savefig('tempo_ts.png')
plt.close()

# Plotar cada uma das 5 componentes reais de X em figuras diferentes, a partir da figura 102
for i in range(5):
    plt.figure(102 + i)  # Começa a numeração das figuras a partir de 102
    plt.plot(ts, X[i, :].real.T)
    plt.grid(True)
    plt.title(f'Componente real do elemento {i + 1} de X')
    plt.xlabel('Tempo (ts)')
    plt.ylabel(f'Componente real {i + 1}')
    plt.savefig(f'componente_real_elemento_{i + 1}.png')
    plt.close()

# Preparar dados
dT = ts[-1] - ts[0]
dt = np.diff(ts, append=ts[-1] + (ts[-1] - ts[-2])) / dT
iavg = True
if iavg:
    Xavg = X @ dt
else:
    Xavg = np.zeros(X.shape[0], dtype=complex)

# Calcular os pesos espaciais usando a regra do trapézio
weights = -np.concatenate([
    [y[1] - y[0]],
    0.5 * (y[2:] - y[:-2]),
    [y[-1] - y[-2]]
])

print("Soma dos pesos temporais (dt):", np.sum(dt))
print("Soma dos pesos espaciais (weights):", np.sum(weights))

# Criar matriz diagonal de pesos espaciais
W_diag = np.concatenate([weights, weights, weights])
W = np.diag(W_diag)

# Calcular modos POD com conjugada transposta
sqrt_W = np.sqrt(W)
sqrt_dt = np.sqrt(dt)
aux = sqrt_W @ (X - Xavg[:, np.newaxis]) @ np.diag(sqrt_dt)
C = (aux @ aux.conj().T) / (N - 1)

# Verificar se C é Hermitiana
is_hermitian = np.allclose(C, C.conj().T)
print("A matriz C é Hermitiana:", is_hermitian)

# Obtém o valor do erro de máquina para o tipo float
epsilon = np.finfo(float).eps
print(f"Erro de máquina (epsilon): {epsilon}")

# Calcular autovalores e autovetores
D, U = np.linalg.eigh(C)

# Ordenar em ordem decrescente
idx = np.argsort(D)[::-1]
D = D[idx]
U = U[:, idx]

# Verificar autovalores negativos e autovalores próximos de zero
num_negatives = np.sum(D < 0)
num_near_zero = np.sum(np.abs(D) < epsilon)
print(f"Número de autovalores negativos: {num_negatives}")
print(f"Número de autovalores próximos de zero (|D| < epsilon): {num_near_zero}")

# Plotar autovalores ajustados (positivos e zero) e negativos separadamente
plot_autovalores(D, epsilon, title='Autovalores Positivos e Negativos Ajustados')

# Zerar autovalores negativos e próximos de zero para evitar problemas de instabilidade
D[D < epsilon] = epsilon

# Normalizar autovetores
for i in range(len(D)):
    U[:, i] = U[:, i] / np.sqrt(U[:, i].conj().T @ U[:, i])

phi = np.diag(1.0 / np.sqrt(np.diag(W))) @ U

# Projetar modos
coefs = np.linalg.solve(phi.conj().T @ W @ phi, phi.conj().T @ W @ (X - Xavg[:, np.newaxis]))

cond_number = np.linalg.cond(C)
print(f"Número de condição da matriz C: {cond_number}")

cumulative_energy = np.cumsum(D) / np.sum(D)
plt.figure()
plt.plot(cumulative_energy)
plt.xlabel('Número de Modos')
plt.ylabel('Energia Cumulativa')
plt.title('Energia Cumulativa dos Autovalores')
plt.grid(True)
plt.savefig('energia_cumulativa_autovalores.png')
plt.close()

# Generate and print cumulative energy percentages for each mode

# Calculate cumulative energy in percentage form for each mode
cumulative_energy_percentage = (np.cumsum(D) / np.sum(D)) * 100

# Print each mode's cumulative energy percentage
for mode, energy in enumerate(cumulative_energy_percentage, start=1):
    print(f"With {mode} mode(s), you have {energy:.8f}% of the total energy.")

# Supondo que as variáveis D, phi, coefs, X, Xavg, Xr, ts, y, ny, Retau já estejam definidas

# 1. Plotar autovalores
plt.figure(103, figsize=(12, 6))
plt.clf()

plt.subplot(1, 2, 1)
plt.plot(D)
plt.yscale('log')
plt.grid(True, which='both')
plt.title('Autovalores (D)')
plt.xlabel('Índice do Autovalor')
plt.ylabel('Valor do Autovalor')

plt.subplot(1, 2, 2)
plt.plot(1 - np.cumsum(D) / np.sum(D))
plt.yscale('log')
plt.grid(True, which='both')
plt.title('Energia Residual Cumulativa')
plt.xlabel('Número de Modos')
plt.ylabel('Energia Residual')

plt.suptitle(f"Valor mínimo de D: {np.min(D)}")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('autovalores_e_energia_residual.png')
plt.close()

# 2. Reconstrução e cálculo do erro
err = []
nmodes_list = np.arange(10, coefs.shape[0] + 1, 10)
for nmodes in nmodes_list:
    Xr = Xavg[:, np.newaxis] + phi[:, :nmodes] @ coefs[:nmodes, :]
    max_err = 100 * np.max(np.abs(X - Xr)) / np.max(np.abs(X))
    fro_err = 100 * np.linalg.norm(X - Xr, 'fro') / np.linalg.norm(X, 'fro')
    err.append([max_err, fro_err])

err = np.array(err).T

plt.figure(104, figsize=(8, 6))
plt.clf()
plt.plot(nmodes_list, err[0, :], label='L_inf')
plt.plot(nmodes_list, err[1, :], label='L2')
plt.yscale('log')
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Número de Modos')
plt.ylabel('Erro de Reconstrução (%)')
plt.title('Erro de Reconstrução em Função do Número de Modos')
plt.tight_layout()
plt.savefig('erro_reconstrucao_numero_modos.png')
plt.close()

nmodes = 100
Xr = Xavg[:, np.newaxis] + phi[:, :nmodes] @ coefs[:nmodes, :]

# 3. Analisar formas dos modos
plt.figure(105, figsize=(18, 6))
plt.clf()

plt.subplot(1, 3, 1)
for i in range(6):
    plt.plot(np.abs(phi[:ny, i]), y, label=f'Modo #{i+1}')
plt.grid(True)
plt.legend(loc='center right')
plt.xlabel('|u|')
plt.ylabel('y')
plt.title('Componentes u dos modos')

plt.subplot(1, 3, 2)
for i in range(6):
    plt.plot(np.abs(phi[ny:2*ny, i]), y)
plt.grid(True)
plt.xlabel('|v|')
plt.ylabel('y')
plt.title('Componentes v dos modos')

plt.subplot(1, 3, 3)
for i in range(6):
    plt.plot(np.abs(phi[2*ny:, i]), y)
plt.grid(True)
plt.xlabel('|w|')
plt.ylabel('y')
plt.title('Componentes w dos modos')

plt.tight_layout()
plt.savefig('formas_modos.png')
plt.close()

# 4. Analisar formas dos modos em escala logarítmica (y+)
plt.figure(106, figsize=(18, 6))
plt.clf()

plt.subplot(1, 3, 1)
for i in range(6):
    plt.plot(np.abs(phi[:ny, i]), (y + 1) * Retau, label=f'Modo #{i+1}')
plt.grid(True)
plt.legend(loc='lower right')
plt.ylim([1e0, Retau])
plt.yscale('log')
plt.xlabel('|u|')
plt.ylabel('y+')
plt.title('Componentes u dos modos (y+)')

plt.subplot(1, 3, 2)
for i in range(6):
    plt.plot(np.abs(phi[ny:2*ny, i]), (y + 1) * Retau)
plt.grid(True)
plt.ylim([1e0, Retau])
plt.yscale('log')
plt.xlabel('|v|')
plt.ylabel('y+')
plt.title('Componentes v dos modos (y+)')

plt.subplot(1, 3, 3)
for i in range(6):
    plt.plot(np.abs(phi[2*ny:, i]), (y + 1) * Retau)
plt.grid(True)
plt.ylim([1e0, Retau])
plt.yscale('log')
plt.xlabel('|w|')
plt.ylabel('y+')
plt.title('Componentes w dos modos (y+)')

plt.tight_layout()
plt.savefig('formas_modos_escala_log_yplus.png')
plt.close()

# 5. Analisar histórico dos coeficientes
plt.figure(107, figsize=(12, 8))
plt.clf()

for i in range(3):
    plt.subplot(3, 1, i + 1)
    ax1 = plt.gca()
    ax2 = ax1.twinx()
    ax1.plot(ts, coefs[i, :].real, 'b-', label='Real')
    ax2.plot(ts, coefs[i, :].imag, 'r--', label='Imag')
    ax1.set_ylabel('Parte Real')
    ax2.set_ylabel('Parte Imaginária')
    plt.title(f'Coeficiente {i+1}')
    ax1.grid(True)
    if i == 2:
        ax1.set_xlabel('Tempo ts')
    if i == 0:
        ax1.legend(loc='upper left')
        ax2.legend(loc='upper right')
plt.tight_layout()
plt.savefig('historico_coeficientes.png')
plt.close()

# 6. Verificar precisão da reconstrução
step = 20  # Número de subplots

plt.figure(108, figsize=(16, 12))
plt.clf()

for i in range(step):
    plt.subplot(4, 5, i + 1)
    plt.plot(np.abs(X[:ny, i]), y, label='Original')
    plt.plot(np.abs(Xr[:ny, i]), y, label='Reconstruído', linestyle='--')
    plt.xlabel('|u|')
    plt.ylabel('y')
    plt.title(f't={ts[i]:.2f}')
    plt.grid(True)
    if i == 0:
        plt.legend()
plt.suptitle('Comparação de |u| Original e Reconstruído')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('comparacao_u_original_reconstruido.png')
plt.close()

plt.figure(109, figsize=(16, 12))
plt.clf()

for i in range(step):
    plt.subplot(4, 5, i + 1)
    plt.plot(np.abs(X[ny:2*ny, i]), y, label='Original')
    plt.plot(np.abs(Xr[ny:2*ny, i]), y, label='Reconstruído', linestyle='--')
    plt.xlabel('|v|')
    plt.ylabel('y')
    plt.title(f't={ts[i]:.2f}')
    plt.grid(True)
    if i == 0:
        plt.legend()
plt.suptitle('Comparação de |v| Original e Reconstruído')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('comparacao_v_original_reconstruido.png')
plt.close()

plt.figure(110, figsize=(16, 12))
plt.clf()

for i in range(step):
    plt.subplot(4, 5, i + 1)
    plt.plot(np.abs(X[2*ny:, i]), y, label='Original')
    plt.plot(np.abs(Xr[2*ny:, i]), y, label='Reconstruído', linestyle='--')
    plt.xlabel('|w|')
    plt.ylabel('y')
    plt.title(f't={ts[i]:.2f}')
    plt.grid(True)
    if i == 0:
        plt.legend()
plt.suptitle('Comparação de |w| Original e Reconstruído')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('comparacao_w_original_reconstruido.png')
plt.close()

# 7. Calcular espectros dos coeficientes (delta_t variável)
plt.figure(111, figsize=(16, 12))
plt.clf()

p = coefs[:, np.concatenate([np.arange(0, 4799, 2), np.arange(4800, coefs.shape[1])])]
delta_t = ts[4801] - ts[4800]
nfft = 2**6
fs = 1 / delta_t

for i in range(16):
    plt.subplot(4, 4, i + 1)
    f_real, Pxx_real = welch(p[i, :].real, fs=fs, nperseg=nfft, noverlap=nfft//2)
    f_imag, Pxx_imag = welch(p[i, :].imag, fs=fs, nperseg=nfft, noverlap=nfft//2)
    plt.plot(f_real, Pxx_real, 'b-', label='Real')
    plt.plot(f_imag, Pxx_imag, 'r--', label='Imag')
    plt.yscale('log')
    plt.xlabel('Frequência (Hz)')
    plt.ylabel('PSD')
    plt.title(f'Modo {i+1}')
    plt.grid(True, which='both')
    if i == 0:
        plt.legend()
plt.suptitle('Espectros dos Coeficientes (delta_t variável)')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('espectros_coeficientes_delta_t_variavel.png')
plt.close()

# 8. Calcular espectros dos coeficientes (delta_t constante)
plt.figure(112, figsize=(16, 12))
plt.clf()

p = coefs[:, :4800]
delta_t = ts[1] - ts[0]
nfft = 2**6
fs = 1 / delta_t

for i in range(16):
    plt.subplot(4, 4, i + 1)
    f_real, Pxx_real = welch(p[i, :].real, fs=fs, nperseg=nfft, noverlap=nfft//2)
    f_imag, Pxx_imag = welch(p[i, :].imag, fs=fs, nperseg=nfft, noverlap=nfft//2)
    plt.plot(f_real, Pxx_real, 'b-', label='Real')
    plt.plot(f_imag, Pxx_imag, 'r--', label='Imag')
    plt.yscale('log')
    plt.xlabel('Frequência (Hz)')
    plt.ylabel('PSD')
    plt.title(f'Modo {i+1}')
    plt.grid(True, which='both')
    if i == 0:
        plt.legend()
plt.suptitle('Espectros dos Coeficientes (delta_t constante)')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('espectros_coeficientes_delta_t_constante.png')
plt.close()

# Selecionar os coeficientes de 1 a 387
indices = np.arange(0, 387)
coeficientes = coefs.flatten()[indices]

# Plotar os coeficientes
plt.figure(figsize=(10, 6))
plt.plot(indices + 1, np.abs(coeficientes))
plt.xlabel('Índice')
plt.ylabel('Magnitude dos Coeficientes')
plt.title('Plot dos Coeficientes de 1 a 387')
plt.grid(True)
plt.savefig('coeficientes_1_a_387.png')
plt.close()

# Defina o número de modos que você deseja utilizar
nmodes = 387  # Escolha o número de modos desejado

# Reconstrução dos dados usando os primeiros nmodes modos
Xr = Xavg[:, np.newaxis] + phi[:, :nmodes] @ coefs[:nmodes, :]

# Salvar apenas os primeiros nmodes coeficientes
scipy.io.savemat('temp_coefs.mat', {'coefs': coefs[:nmodes, :], 'ts': ts})

# Salvar apenas os primeiros nmodes modos espaciais
scipy.io.savemat('spatial_modes.mat', {'phi': phi[:, :nmodes]})

# Salvar Xavg e y (sem alterações)
scipy.io.savemat('mean_flow.mat', {'Xavg': Xavg, 'y': y})

# (Opcional) Salvar o valor de nmodes para referência futura
scipy.io.savemat('parameters.mat', {'nmodes': nmodes})
# Out:
# Processando arquivos .mat: 100%|██████████| 10401/10401 [00:55<00:00, 187.83it/s]
# Número de arquivos processados: 10401
# Tamanho de ts: (10401,)
# Soma dos pesos temporais (dt): 1.0001250000000004
# Soma dos pesos espaciais (weights): 2.000301181303796
# A matriz C é Hermitiana: True
# Erro de máquina (epsilon): 2.220446049250313e-16
# Número de autovalores negativos: 72
# Número de autovalores próximos de zero (|D| < epsilon): 266
# Número de condição da matriz C: 1.3060662330527177e+33
# With 1 mode(s), you have 34.98241042% of the total energy.
# With 2 mode(s), you have 67.81909534% of the total energy.
# With 3 mode(s), you have 74.65402199% of the total energy.
# With 4 mode(s), you have 80.87495164% of the total energy.
# With 5 mode(s), you have 83.70097183% of the total energy.
# With 6 mode(s), you have 86.26156804% of the total energy.
# With 7 mode(s), you have 87.89943203% of the total energy.
# With 8 mode(s), you have 89.41012556% of the total energy.
# With 9 mode(s), you have 90.55593282% of the total energy.
# With 10 mode(s), you have 91.60660287% of the total energy.
# With 11 mode(s), you have 92.53460175% of the total energy.
# With 12 mode(s), you have 93.39008430% of the total energy.
# With 13 mode(s), you have 94.13445738% of the total energy.
# With 14 mode(s), you have 94.79530809% of the total energy.
# With 15 mode(s), you have 95.38191189% of the total energy.
# With 16 mode(s), you have 95.88891217% of the total energy.
# With 17 mode(s), you have 96.35978750% of the total energy.
# With 18 mode(s), you have 96.80502838% of the total energy.
# With 19 mode(s), you have 97.21488182% of the total energy.
# With 20 mode(s), you have 97.54392212% of the total energy.
# With 21 mode(s), you have 97.85406612% of the total energy.
# With 22 mode(s), you have 98.11787138% of the total energy.
# With 23 mode(s), you have 98.36569230% of the total energy.
# With 24 mode(s), you have 98.56719005% of the total energy.
# With 25 mode(s), you have 98.75441485% of the total energy.
# With 26 mode(s), you have 98.90864052% of the total energy.
# With 27 mode(s), you have 99.04573267% of the total energy.
# With 28 mode(s), you have 99.16198894% of the total energy.
# With 29 mode(s), you have 99.26647917% of the total energy.
# With 30 mode(s), you have 99.35214276% of the total energy.
# With 31 mode(s), you have 99.43105489% of the total energy.
# With 32 mode(s), you have 99.49927785% of the total energy.
# With 33 mode(s), you have 99.55695701% of the total energy.
# With 34 mode(s), you have 99.60954209% of the total energy.
# With 35 mode(s), you have 99.65377682% of the total energy.
# With 36 mode(s), you have 99.69470279% of the total energy.
# With 37 mode(s), you have 99.73202552% of the total energy.
# With 38 mode(s), you have 99.76172792% of the total energy.
# With 39 mode(s), you have 99.78981979% of the total energy.
# With 40 mode(s), you have 99.81351388% of the total energy.
# With 41 mode(s), you have 99.83583836% of the total energy.
# With 42 mode(s), you have 99.85362558% of the total energy.
# With 43 mode(s), you have 99.87023164% of the total energy.
# With 44 mode(s), you have 99.88418529% of the total energy.
# With 45 mode(s), you have 99.89731087% of the total energy.
# With 46 mode(s), you have 99.90800880% of the total energy.
# With 47 mode(s), you have 99.91815743% of the total energy.
# With 48 mode(s), you have 99.92667767% of the total energy.
# With 49 mode(s), you have 99.93443730% of the total energy.
# With 50 mode(s), you have 99.94148820% of the total energy.
# With 51 mode(s), you have 99.94753969% of the total energy.
# With 52 mode(s), you have 99.95300089% of the total energy.
# With 53 mode(s), you have 99.95784755% of the total energy.
# With 54 mode(s), you have 99.96219163% of the total energy.
# With 55 mode(s), you have 99.96589133% of the total energy.
# With 56 mode(s), you have 99.96935350% of the total energy.
# With 57 mode(s), you have 99.97235071% of the total energy.
# With 58 mode(s), you have 99.97500097% of the total energy.
# With 59 mode(s), you have 99.97737862% of the total energy.
# With 60 mode(s), you have 99.97949235% of the total energy.
# With 61 mode(s), you have 99.98138441% of the total energy.
# With 62 mode(s), you have 99.98312460% of the total energy.
# With 63 mode(s), you have 99.98462993% of the total energy.
# With 64 mode(s), you have 99.98609284% of the total energy.
# With 65 mode(s), you have 99.98731236% of the total energy.
# With 66 mode(s), you have 99.98844178% of the total energy.
# With 67 mode(s), you have 99.98938644% of the total energy.
# With 68 mode(s), you have 99.99030465% of the total energy.
# With 69 mode(s), you have 99.99105653% of the total energy.
# With 70 mode(s), you have 99.99178223% of the total energy.
# With 71 mode(s), you have 99.99240267% of the total energy.
# With 72 mode(s), you have 99.99300918% of the total energy.
# With 73 mode(s), you have 99.99351107% of the total energy.
# With 74 mode(s), you have 99.99400439% of the total energy.
# With 75 mode(s), you have 99.99440782% of the total energy.
# With 76 mode(s), you have 99.99479153% of the total energy.
# With 77 mode(s), you have 99.99512274% of the total energy.
# With 78 mode(s), you have 99.99543837% of the total energy.
# With 79 mode(s), you have 99.99570862% of the total energy.
# With 80 mode(s), you have 99.99596800% of the total energy.
# With 81 mode(s), you have 99.99618956% of the total energy.
# With 82 mode(s), you have 99.99639808% of the total energy.
# With 83 mode(s), you have 99.99658422% of the total energy.
# With 84 mode(s), you have 99.99675086% of the total energy.
# With 85 mode(s), you have 99.99690315% of the total energy.
# With 86 mode(s), you have 99.99704647% of the total energy.
# With 87 mode(s), you have 99.99717196% of the total energy.
# With 88 mode(s), you have 99.99728871% of the total energy.
# With 89 mode(s), you have 99.99739303% of the total energy.
# With 90 mode(s), you have 99.99748591% of the total energy.
# With 91 mode(s), you have 99.99757064% of the total energy.
# With 92 mode(s), you have 99.99764890% of the total energy.
# With 93 mode(s), you have 99.99772037% of the total energy.
# With 94 mode(s), you have 99.99778503% of the total energy.
# With 95 mode(s), you have 99.99784426% of the total energy.
# With 96 mode(s), you have 99.99789841% of the total energy.
# With 97 mode(s), you have 99.99794722% of the total energy.
# With 98 mode(s), you have 99.99799215% of the total energy.
# With 99 mode(s), you have 99.99803265% of the total energy.
# With 100 mode(s), you have 99.99806884% of the total energy.
# With 101 mode(s), you have 99.99810398% of the total energy.
# With 102 mode(s), you have 99.99813510% of the total energy.
# With 103 mode(s), you have 99.99816377% of the total energy.
# With 104 mode(s), you have 99.99818945% of the total energy.
# With 105 mode(s), you have 99.99821334% of the total energy.
# With 106 mode(s), you have 99.99823517% of the total energy.
# With 107 mode(s), you have 99.99825543% of the total energy.
# With 108 mode(s), you have 99.99827313% of the total energy.
# With 109 mode(s), you have 99.99829014% of the total energy.
# With 110 mode(s), you have 99.99830509% of the total energy.
# With 111 mode(s), you have 99.99831933% of the total energy.
# With 112 mode(s), you have 99.99833196% of the total energy.
# With 113 mode(s), you have 99.99834405% of the total energy.
# With 114 mode(s), you have 99.99835459% of the total energy.
# With 115 mode(s), you have 99.99836480% of the total energy.
# With 116 mode(s), you have 99.99837391% of the total energy.
# With 117 mode(s), you have 99.99838256% of the total energy.
# With 118 mode(s), you have 99.99839025% of the total energy.
# With 119 mode(s), you have 99.99839742% of the total energy.
# With 120 mode(s), you have 99.99840375% of the total energy.
# With 121 mode(s), you have 99.99840983% of the total energy.
# With 122 mode(s), you have 99.99841581% of the total energy.
# With 123 mode(s), you have 99.99842179% of the total energy.
# With 124 mode(s), you have 99.99842777% of the total energy.
# With 125 mode(s), you have 99.99843374% of the total energy.
# With 126 mode(s), you have 99.99843972% of the total energy.
# With 127 mode(s), you have 99.99844570% of the total energy.
# With 128 mode(s), you have 99.99845168% of the total energy.
# With 129 mode(s), you have 99.99845766% of the total energy.
# With 130 mode(s), you have 99.99846363% of the total energy.
# With 131 mode(s), you have 99.99846961% of the total energy.
# With 132 mode(s), you have 99.99847559% of the total energy.
# With 133 mode(s), you have 99.99848157% of the total energy.
# With 134 mode(s), you have 99.99848755% of the total energy.
# With 135 mode(s), you have 99.99849352% of the total energy.
# With 136 mode(s), you have 99.99849950% of the total energy.
# With 137 mode(s), you have 99.99850548% of the total energy.
# With 138 mode(s), you have 99.99851146% of the total energy.
# With 139 mode(s), you have 99.99851744% of the total energy.
# With 140 mode(s), you have 99.99852342% of the total energy.
# With 141 mode(s), you have 99.99852939% of the total energy.
# With 142 mode(s), you have 99.99853537% of the total energy.
# With 143 mode(s), you have 99.99854135% of the total energy.
# With 144 mode(s), you have 99.99854733% of the total energy.
# With 145 mode(s), you have 99.99855331% of the total energy.
# With 146 mode(s), you have 99.99855928% of the total energy.
# With 147 mode(s), you have 99.99856526% of the total energy.
# With 148 mode(s), you have 99.99857124% of the total energy.
# With 149 mode(s), you have 99.99857722% of the total energy.
# With 150 mode(s), you have 99.99858320% of the total energy.
# With 151 mode(s), you have 99.99858917% of the total energy.
# With 152 mode(s), you have 99.99859515% of the total energy.
# With 153 mode(s), you have 99.99860113% of the total energy.
# With 154 mode(s), you have 99.99860711% of the total energy.
# With 155 mode(s), you have 99.99861309% of the total energy.
# With 156 mode(s), you have 99.99861906% of the total energy.
# With 157 mode(s), you have 99.99862504% of the total energy.
# With 158 mode(s), you have 99.99863102% of the total energy.
# With 159 mode(s), you have 99.99863700% of the total energy.
# With 160 mode(s), you have 99.99864298% of the total energy.
# With 161 mode(s), you have 99.99864895% of the total energy.
# With 162 mode(s), you have 99.99865493% of the total energy.
# With 163 mode(s), you have 99.99866091% of the total energy.
# With 164 mode(s), you have 99.99866689% of the total energy.
# With 165 mode(s), you have 99.99867287% of the total energy.
# With 166 mode(s), you have 99.99867885% of the total energy.
# With 167 mode(s), you have 99.99868482% of the total energy.
# With 168 mode(s), you have 99.99869080% of the total energy.
# With 169 mode(s), you have 99.99869678% of the total energy.
# With 170 mode(s), you have 99.99870276% of the total energy.
# With 171 mode(s), you have 99.99870874% of the total energy.
# With 172 mode(s), you have 99.99871471% of the total energy.
# With 173 mode(s), you have 99.99872069% of the total energy.
# With 174 mode(s), you have 99.99872667% of the total energy.
# With 175 mode(s), you have 99.99873265% of the total energy.
# With 176 mode(s), you have 99.99873863% of the total energy.
# With 177 mode(s), you have 99.99874460% of the total energy.
# With 178 mode(s), you have 99.99875058% of the total energy.
# With 179 mode(s), you have 99.99875656% of the total energy.
# With 180 mode(s), you have 99.99876254% of the total energy.
# With 181 mode(s), you have 99.99876852% of the total energy.
# With 182 mode(s), you have 99.99877449% of the total energy.
# With 183 mode(s), you have 99.99878047% of the total energy.
# With 184 mode(s), you have 99.99878645% of the total energy.
# With 185 mode(s), you have 99.99879243% of the total energy.
# With 186 mode(s), you have 99.99879841% of the total energy.
# With 187 mode(s), you have 99.99880438% of the total energy.
# With 188 mode(s), you have 99.99881036% of the total energy.
# With 189 mode(s), you have 99.99881634% of the total energy.
# With 190 mode(s), you have 99.99882232% of the total energy.
# With 191 mode(s), you have 99.99882830% of the total energy.
# With 192 mode(s), you have 99.99883428% of the total energy.
# With 193 mode(s), you have 99.99884025% of the total energy.
# With 194 mode(s), you have 99.99884623% of the total energy.
# With 195 mode(s), you have 99.99885221% of the total energy.
# With 196 mode(s), you have 99.99885819% of the total energy.
# With 197 mode(s), you have 99.99886417% of the total energy.
# With 198 mode(s), you have 99.99887014% of the total energy.
# With 199 mode(s), you have 99.99887612% of the total energy.
# With 200 mode(s), you have 99.99888210% of the total energy.
# With 201 mode(s), you have 99.99888808% of the total energy.
# With 202 mode(s), you have 99.99889406% of the total energy.
# With 203 mode(s), you have 99.99890003% of the total energy.
# With 204 mode(s), you have 99.99890601% of the total energy.
# With 205 mode(s), you have 99.99891199% of the total energy.
# With 206 mode(s), you have 99.99891797% of the total energy.
# With 207 mode(s), you have 99.99892395% of the total energy.
# With 208 mode(s), you have 99.99892992% of the total energy.
# With 209 mode(s), you have 99.99893590% of the total energy.
# With 210 mode(s), you have 99.99894188% of the total energy.
# With 211 mode(s), you have 99.99894786% of the total energy.
# With 212 mode(s), you have 99.99895384% of the total energy.
# With 213 mode(s), you have 99.99895981% of the total energy.
# With 214 mode(s), you have 99.99896579% of the total energy.
# With 215 mode(s), you have 99.99897177% of the total energy.
# With 216 mode(s), you have 99.99897775% of the total energy.
# With 217 mode(s), you have 99.99898373% of the total energy.
# With 218 mode(s), you have 99.99898971% of the total energy.
# With 219 mode(s), you have 99.99899568% of the total energy.
# With 220 mode(s), you have 99.99900166% of the total energy.
# With 221 mode(s), you have 99.99900764% of the total energy.
# With 222 mode(s), you have 99.99901362% of the total energy.
# With 223 mode(s), you have 99.99901960% of the total energy.
# With 224 mode(s), you have 99.99902557% of the total energy.
# With 225 mode(s), you have 99.99903155% of the total energy.
# With 226 mode(s), you have 99.99903753% of the total energy.
# With 227 mode(s), you have 99.99904351% of the total energy.
# With 228 mode(s), you have 99.99904949% of the total energy.
# With 229 mode(s), you have 99.99905546% of the total energy.
# With 230 mode(s), you have 99.99906144% of the total energy.
# With 231 mode(s), you have 99.99906742% of the total energy.
# With 232 mode(s), you have 99.99907340% of the total energy.
# With 233 mode(s), you have 99.99907938% of the total energy.
# With 234 mode(s), you have 99.99908535% of the total energy.
# With 235 mode(s), you have 99.99909133% of the total energy.
# With 236 mode(s), you have 99.99909731% of the total energy.
# With 237 mode(s), you have 99.99910329% of the total energy.
# With 238 mode(s), you have 99.99910927% of the total energy.
# With 239 mode(s), you have 99.99911524% of the total energy.
# With 240 mode(s), you have 99.99912122% of the total energy.
# With 241 mode(s), you have 99.99912720% of the total energy.
# With 242 mode(s), you have 99.99913318% of the total energy.
# With 243 mode(s), you have 99.99913916% of the total energy.
# With 244 mode(s), you have 99.99914514% of the total energy.
# With 245 mode(s), you have 99.99915111% of the total energy.
# With 246 mode(s), you have 99.99915709% of the total energy.
# With 247 mode(s), you have 99.99916307% of the total energy.
# With 248 mode(s), you have 99.99916905% of the total energy.
# With 249 mode(s), you have 99.99917503% of the total energy.
# With 250 mode(s), you have 99.99918100% of the total energy.
# With 251 mode(s), you have 99.99918698% of the total energy.
# With 252 mode(s), you have 99.99919296% of the total energy.
# With 253 mode(s), you have 99.99919894% of the total energy.
# With 254 mode(s), you have 99.99920492% of the total energy.
# With 255 mode(s), you have 99.99921089% of the total energy.
# With 256 mode(s), you have 99.99921687% of the total energy.
# With 257 mode(s), you have 99.99922285% of the total energy.
# With 258 mode(s), you have 99.99922883% of the total energy.
# With 259 mode(s), you have 99.99923481% of the total energy.
# With 260 mode(s), you have 99.99924078% of the total energy.
# With 261 mode(s), you have 99.99924676% of the total energy.
# With 262 mode(s), you have 99.99925274% of the total energy.
# With 263 mode(s), you have 99.99925872% of the total energy.
# With 264 mode(s), you have 99.99926470% of the total energy.
# With 265 mode(s), you have 99.99927067% of the total energy.
# With 266 mode(s), you have 99.99927665% of the total energy.
# With 267 mode(s), you have 99.99928263% of the total energy.
# With 268 mode(s), you have 99.99928861% of the total energy.
# With 269 mode(s), you have 99.99929459% of the total energy.
# With 270 mode(s), you have 99.99930057% of the total energy.
# With 271 mode(s), you have 99.99930654% of the total energy.
# With 272 mode(s), you have 99.99931252% of the total energy.
# With 273 mode(s), you have 99.99931850% of the total energy.
# With 274 mode(s), you have 99.99932448% of the total energy.
# With 275 mode(s), you have 99.99933046% of the total energy.
# With 276 mode(s), you have 99.99933643% of the total energy.
# With 277 mode(s), you have 99.99934241% of the total energy.
# With 278 mode(s), you have 99.99934839% of the total energy.
# With 279 mode(s), you have 99.99935437% of the total energy.
# With 280 mode(s), you have 99.99936035% of the total energy.
# With 281 mode(s), you have 99.99936632% of the total energy.
# With 282 mode(s), you have 99.99937230% of the total energy.
# With 283 mode(s), you have 99.99937828% of the total energy.
# With 284 mode(s), you have 99.99938426% of the total energy.
# With 285 mode(s), you have 99.99939024% of the total energy.
# With 286 mode(s), you have 99.99939621% of the total energy.
# With 287 mode(s), you have 99.99940219% of the total energy.
# With 288 mode(s), you have 99.99940817% of the total energy.
# With 289 mode(s), you have 99.99941415% of the total energy.
# With 290 mode(s), you have 99.99942013% of the total energy.
# With 291 mode(s), you have 99.99942610% of the total energy.
# With 292 mode(s), you have 99.99943208% of the total energy.
# With 293 mode(s), you have 99.99943806% of the total energy.
# With 294 mode(s), you have 99.99944404% of the total energy.
# With 295 mode(s), you have 99.99945002% of the total energy.
# With 296 mode(s), you have 99.99945600% of the total energy.
# With 297 mode(s), you have 99.99946197% of the total energy.
# With 298 mode(s), you have 99.99946795% of the total energy.
# With 299 mode(s), you have 99.99947393% of the total energy.
# With 300 mode(s), you have 99.99947991% of the total energy.
# With 301 mode(s), you have 99.99948589% of the total energy.
# With 302 mode(s), you have 99.99949186% of the total energy.
# With 303 mode(s), you have 99.99949784% of the total energy.
# With 304 mode(s), you have 99.99950382% of the total energy.
# With 305 mode(s), you have 99.99950980% of the total energy.
# With 306 mode(s), you have 99.99951578% of the total energy.
# With 307 mode(s), you have 99.99952175% of the total energy.
# With 308 mode(s), you have 99.99952773% of the total energy.
# With 309 mode(s), you have 99.99953371% of the total energy.
# With 310 mode(s), you have 99.99953969% of the total energy.
# With 311 mode(s), you have 99.99954567% of the total energy.
# With 312 mode(s), you have 99.99955164% of the total energy.
# With 313 mode(s), you have 99.99955762% of the total energy.
# With 314 mode(s), you have 99.99956360% of the total energy.
# With 315 mode(s), you have 99.99956958% of the total energy.
# With 316 mode(s), you have 99.99957556% of the total energy.
# With 317 mode(s), you have 99.99958153% of the total energy.
# With 318 mode(s), you have 99.99958751% of the total energy.
# With 319 mode(s), you have 99.99959349% of the total energy.
# With 320 mode(s), you have 99.99959947% of the total energy.
# With 321 mode(s), you have 99.99960545% of the total energy.
# With 322 mode(s), you have 99.99961143% of the total energy.
# With 323 mode(s), you have 99.99961740% of the total energy.
# With 324 mode(s), you have 99.99962338% of the total energy.
# With 325 mode(s), you have 99.99962936% of the total energy.
# With 326 mode(s), you have 99.99963534% of the total energy.
# With 327 mode(s), you have 99.99964132% of the total energy.
# With 328 mode(s), you have 99.99964729% of the total energy.
# With 329 mode(s), you have 99.99965327% of the total energy.
# With 330 mode(s), you have 99.99965925% of the total energy.
# With 331 mode(s), you have 99.99966523% of the total energy.
# With 332 mode(s), you have 99.99967121% of the total energy.
# With 333 mode(s), you have 99.99967718% of the total energy.
# With 334 mode(s), you have 99.99968316% of the total energy.
# With 335 mode(s), you have 99.99968914% of the total energy.
# With 336 mode(s), you have 99.99969512% of the total energy.
# With 337 mode(s), you have 99.99970110% of the total energy.
# With 338 mode(s), you have 99.99970707% of the total energy.
# With 339 mode(s), you have 99.99971305% of the total energy.
# With 340 mode(s), you have 99.99971903% of the total energy.
# With 341 mode(s), you have 99.99972501% of the total energy.
# With 342 mode(s), you have 99.99973099% of the total energy.
# With 343 mode(s), you have 99.99973696% of the total energy.
# With 344 mode(s), you have 99.99974294% of the total energy.
# With 345 mode(s), you have 99.99974892% of the total energy.
# With 346 mode(s), you have 99.99975490% of the total energy.
# With 347 mode(s), you have 99.99976088% of the total energy.
# With 348 mode(s), you have 99.99976686% of the total energy.
# With 349 mode(s), you have 99.99977283% of the total energy.
# With 350 mode(s), you have 99.99977881% of the total energy.
# With 351 mode(s), you have 99.99978479% of the total energy.
# With 352 mode(s), you have 99.99979077% of the total energy.
# With 353 mode(s), you have 99.99979675% of the total energy.
# With 354 mode(s), you have 99.99980272% of the total energy.
# With 355 mode(s), you have 99.99980870% of the total energy.
# With 356 mode(s), you have 99.99981468% of the total energy.
# With 357 mode(s), you have 99.99982066% of the total energy.
# With 358 mode(s), you have 99.99982664% of the total energy.
# With 359 mode(s), you have 99.99983261% of the total energy.
# With 360 mode(s), you have 99.99983859% of the total energy.
# With 361 mode(s), you have 99.99984457% of the total energy.
# With 362 mode(s), you have 99.99985055% of the total energy.
# With 363 mode(s), you have 99.99985653% of the total energy.
# With 364 mode(s), you have 99.99986250% of the total energy.
# With 365 mode(s), you have 99.99986848% of the total energy.
# With 366 mode(s), you have 99.99987446% of the total energy.
# With 367 mode(s), you have 99.99988044% of the total energy.
# With 368 mode(s), you have 99.99988642% of the total energy.
# With 369 mode(s), you have 99.99989239% of the total energy.
# With 370 mode(s), you have 99.99989837% of the total energy.
# With 371 mode(s), you have 99.99990435% of the total energy.
# With 372 mode(s), you have 99.99991033% of the total energy.
# With 373 mode(s), you have 99.99991631% of the total energy.
# With 374 mode(s), you have 99.99992229% of the total energy.
# With 375 mode(s), you have 99.99992826% of the total energy.
# With 376 mode(s), you have 99.99993424% of the total energy.
# With 377 mode(s), you have 99.99994022% of the total energy.
# With 378 mode(s), you have 99.99994620% of the total energy.
# With 379 mode(s), you have 99.99995218% of the total energy.
# With 380 mode(s), you have 99.99995815% of the total energy.
# With 381 mode(s), you have 99.99996413% of the total energy.
# With 382 mode(s), you have 99.99997011% of the total energy.
# With 383 mode(s), you have 99.99997609% of the total energy.
# With 384 mode(s), you have 99.99998207% of the total energy.
# With 385 mode(s), you have 99.99998804% of the total energy.
# With 386 mode(s), you have 99.99999402% of the total energy.
# With 387 mode(s), you have 100.00000000% of the total energy.
